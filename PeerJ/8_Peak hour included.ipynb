# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('C:\\Users\\arif\\OneDrive\\Journal Paper\\Code\\Irshad\\Dataset\\6_Dataset_cyclic_holi.csv', parse_dates=['date_and_hour'], index_col='date_and_hour')

# %%
df
# Out:
#                      System_load  Year  Month_of_year  Day_Of_Week  \
# date_and_hour
# 2015-01-01 00:00:00       8288.0  2015              1            3
# 2015-01-01 01:00:00       8099.0  2015              1            3
# 2015-01-01 02:00:00       7994.0  2015              1            3
# 2015-01-01 03:00:00       7965.0  2015              1            3
# 2015-01-01 04:00:00       8120.0  2015              1            3
# ...                          ...   ...            ...          ...
# 2020-04-30 19:00:00      16858.0  2020              4            3
# 2020-04-30 20:00:00      17105.0  2020              4            3
# 2020-04-30 21:00:00      16824.0  2020              4            3
# 2020-04-30 22:00:00      16332.0  2020              4            3
# 2020-04-30 23:00:00      15003.0  2020              4            3
#
#                      hour_of_day  holiday
# date_and_hour
# 2015-01-01 00:00:00            0        0
# 2015-01-01 01:00:00            1        0
# ...

# %% [markdown]
# ![WhatsApp%20Image%202022-08-02%20at%2012.07.23%20PM.jpeg](attachment:WhatsApp%20Image%202022-08-02%20at%2012.07.23%20PM.jpeg)

# %%
24*31*6*2+24*31*5
# Out:
# 12648

# %%
df[df['Month_of_year'] == 1]
# Out:
#                      System_load  Year  Month_of_year  Day_Of_Week  \
# date_and_hour
# 2015-01-01 00:00:00       8288.0  2015              1            3
# 2015-01-01 01:00:00       8099.0  2015              1            3
# 2015-01-01 02:00:00       7994.0  2015              1            3
# 2015-01-01 03:00:00       7965.0  2015              1            3
# 2015-01-01 04:00:00       8120.0  2015              1            3
# ...                          ...   ...            ...          ...
# 2020-01-31 19:00:00      11479.0  2020              1            4
# 2020-01-31 20:00:00      10786.0  2020              1            4
# 2020-01-31 21:00:00      10542.0  2020              1            4
# 2020-01-31 22:00:00       9887.0  2020              1            4
# 2020-01-31 23:00:00       8959.0  2020              1            4
#
#                      hour_of_day  holiday
# date_and_hour
# 2015-01-01 00:00:00            0        0
# 2015-01-01 01:00:00            1        0
# ...

# %%
#part 1
df['D_to_F_peak_M1']=df['Month_of_year'] == 12
df['D_to_F_peak_M2']=df['Month_of_year'] == 1 
df['D_to_F_peak_M3']=df['Month_of_year'] == 2
df['D_to_F_peak_M']=df['D_to_F_peak_M3']|df['D_to_F_peak_M2']|df['D_to_F_peak_M1']
del df['D_to_F_peak_M1']
del df['D_to_F_peak_M2']
del df['D_to_F_peak_M3']

df['D_to_F_peak_H1']=df['hour_of_day'] == 17
df['D_to_F_peak_H2']=df['hour_of_day'] == 18
df['D_to_F_peak_H3']=df['hour_of_day'] == 19
df['D_to_F_peak_H4']=df['hour_of_day'] == 20
df['D_to_F_peak_H5']=df['hour_of_day'] == 21
df['D_to_F_peak_H6']=df['D_to_F_peak_H1']|df['D_to_F_peak_H2']|df['D_to_F_peak_H3']|df['D_to_F_peak_H4']|df['D_to_F_peak_H5']

del df['D_to_F_peak_H1']
del df['D_to_F_peak_H2']
del df['D_to_F_peak_H3']
del df['D_to_F_peak_H4']
del df['D_to_F_peak_H5']

df['winter_peak']=(df['D_to_F_peak_H6'] & df['D_to_F_peak_M'])*1
del df['D_to_F_peak_H6']
del df['D_to_F_peak_M']
df.head(24)
# Out:
#                      System_load  Year  Month_of_year  Day_Of_Week  \
# date_and_hour
# 2015-01-01 00:00:00       8288.0  2015              1            3
# 2015-01-01 01:00:00       8099.0  2015              1            3
# 2015-01-01 02:00:00       7994.0  2015              1            3
# 2015-01-01 03:00:00       7965.0  2015              1            3
# 2015-01-01 04:00:00       8120.0  2015              1            3
# 2015-01-01 05:00:00       8462.0  2015              1            3
# 2015-01-01 06:00:00       9200.0  2015              1            3
# 2015-01-01 07:00:00       9657.0  2015              1            3
# 2015-01-01 08:00:00      10032.0  2015              1            3
# 2015-01-01 09:00:00      10072.0  2015              1            3
# 2015-01-01 10:00:00       9932.0  2015              1            3
# 2015-01-01 11:00:00       9980.0  2015              1            3
# 2015-01-01 12:00:00       9392.0  2015              1            3
# ...

# %%
df['D_to_F_peak_M1']=df[ 'Month_of_year'] == 3 
df['D_to_F_peak_M2']=df[ 'Month_of_year'] == 4 
df['D_to_F_peak_M3']=df[ 'Month_of_year'] == 5 
df['D_to_F_peak_M']=df[ 'D_to_F_peak_M3']|df[ 'D_to_F_peak_M2']|df['D_to_F_peak_M1'] 
del df['D_to_F_peak_M3']
del df['D_to_F_peak_M1']
del df['D_to_F_peak_M2']

df['D_to_F_peak_H1']= df['hour_of_day'] == 18 
df['D_to_F_peak_H2']= df['hour_of_day'] == 19
df['D_to_F_peak_H3']= df['hour_of_day'] == 20 
df['D_to_F_peak_H4']= df['hour_of_day'] == 21 
df['D_to_F_peak_H5']= df['hour_of_day'] == 22 
df['D_to_F_peak_H6']=df['D_to_F_peak_H1']|df['D_to_F_peak_H2']|df['D_to_F_peak_H3']|df['D_to_F_peak_H4']|df['D_to_F_peak_H5']
del df['D_to_F_peak_H1']
del df['D_to_F_peak_H2']
del df['D_to_F_peak_H3']
del df['D_to_F_peak_H4'] 
del df['D_to_F_peak_H5']

df['Spring_Peak']=(df['D_to_F_peak_H6'] & df['D_to_F_peak_M'])*1
del df['D_to_F_peak_H6']
del df['D_to_F_peak_M']
df.head(24)
# Out:
#                      System_load  Year  Month_of_year  Day_Of_Week  \
# date_and_hour
# 2015-01-01 00:00:00       8288.0  2015              1            3
# 2015-01-01 01:00:00       8099.0  2015              1            3
# 2015-01-01 02:00:00       7994.0  2015              1            3
# 2015-01-01 03:00:00       7965.0  2015              1            3
# 2015-01-01 04:00:00       8120.0  2015              1            3
# 2015-01-01 05:00:00       8462.0  2015              1            3
# 2015-01-01 06:00:00       9200.0  2015              1            3
# 2015-01-01 07:00:00       9657.0  2015              1            3
# 2015-01-01 08:00:00      10032.0  2015              1            3
# 2015-01-01 09:00:00      10072.0  2015              1            3
# 2015-01-01 10:00:00       9932.0  2015              1            3
# 2015-01-01 11:00:00       9980.0  2015              1            3
# 2015-01-01 12:00:00       9392.0  2015              1            3
# ...

# %%
df['D_to_F_peak_M1']=df[ 'Month_of_year'] == 6 
df['D_to_F_peak_M2']=df[ 'Month_of_year'] == 7 
df['D_to_F_peak_M3']=df[ 'Month_of_year'] == 8 
df['D_to_F_peak_M']=df[ 'D_to_F_peak_M3' ]|df[ 'D_to_F_peak_M2']|df[ 'D_to_F_peak_M1'] 
del df['D_to_F_peak_M3']
del df['D_to_F_peak_M1']
del df['D_to_F_peak_M2']

df['D_to_F_peak_H1']=df['hour_of_day'] == 19 
df['D_to_F_peak_H2']=df['hour_of_day'] == 20
df['D_to_F_peak_H3']=df['hour_of_day'] == 21 
df['D_to_F_peak_H4']=df['hour_of_day'] == 22 
df['D_to_F_peak_H5']=df['hour_of_day'] == 23 
df['D_to_F_peak_H6']=df['D_to_F_peak_H1']|df['D_to_F_peak_H2']|df['D_to_F_peak_H3']|df['D_to_F_peak_H4']|df['D_to_F_peak_H5']

del df['D_to_F_peak_H1']
del df['D_to_F_peak_H2']
del df['D_to_F_peak_H3']
del df['D_to_F_peak_H4'] 
del df['D_to_F_peak_H5']

df['Summer_Peak']=(df['D_to_F_peak_H6'] & df['D_to_F_peak_M'])*1

del df['D_to_F_peak_H6'] 
del df['D_to_F_peak_M']

df.head(24)
# Out:
#                      System_load  Year  Month_of_year  Day_Of_Week  \
# date_and_hour
# 2015-01-01 00:00:00       8288.0  2015              1            3
# 2015-01-01 01:00:00       8099.0  2015              1            3
# 2015-01-01 02:00:00       7994.0  2015              1            3
# 2015-01-01 03:00:00       7965.0  2015              1            3
# 2015-01-01 04:00:00       8120.0  2015              1            3
# 2015-01-01 05:00:00       8462.0  2015              1            3
# 2015-01-01 06:00:00       9200.0  2015              1            3
# 2015-01-01 07:00:00       9657.0  2015              1            3
# 2015-01-01 08:00:00      10032.0  2015              1            3
# 2015-01-01 09:00:00      10072.0  2015              1            3
# 2015-01-01 10:00:00       9932.0  2015              1            3
# 2015-01-01 11:00:00       9980.0  2015              1            3
# 2015-01-01 12:00:00       9392.0  2015              1            3
# ...

# %%
df['D_to_F_peak_M1']=df[ 'Month_of_year'] == 9 
df['D_to_F_peak_M2']=df[ 'Month_of_year'] == 10 
df['D_to_F_peak_M3']=df[ 'Month_of_year'] == 11
df['D_to_F_peak_M']=df[ 'D_to_F_peak_M3' ]|df[ 'D_to_F_peak_M2']|df[ 'D_to_F_peak_M1'] 
del df['D_to_F_peak_M3']
del df['D_to_F_peak_M1']
del df['D_to_F_peak_M2']

df['D_to_F_peak_H1']= df['hour_of_day'] == 18 
df['D_to_F_peak_H2']= df['hour_of_day'] == 19
df['D_to_F_peak_H3']= df['hour_of_day'] == 20 
df['D_to_F_peak_H4']= df['hour_of_day'] == 21 
df['D_to_F_peak_H5']= df['hour_of_day'] == 22  
df['D_to_F_peak_H6']=df['D_to_F_peak_H1']|df['D_to_F_peak_H2']|df['D_to_F_peak_H3']|df['D_to_F_peak_H4']|df['D_to_F_peak_H5']

del df['D_to_F_peak_H1']
del df['D_to_F_peak_H2']
del df['D_to_F_peak_H3']
del df['D_to_F_peak_H4'] 
del df['D_to_F_peak_H5']

df['Autumn_peak']=(df['D_to_F_peak_H6'] & df['D_to_F_peak_M'])*1

del df['D_to_F_peak_H6'] 
del df['D_to_F_peak_M']

df.head(24)
# Out:
#                      System_load  Year  Month_of_year  Day_Of_Week  \
# date_and_hour
# 2015-01-01 00:00:00       8288.0  2015              1            3
# 2015-01-01 01:00:00       8099.0  2015              1            3
# 2015-01-01 02:00:00       7994.0  2015              1            3
# 2015-01-01 03:00:00       7965.0  2015              1            3
# 2015-01-01 04:00:00       8120.0  2015              1            3
# 2015-01-01 05:00:00       8462.0  2015              1            3
# 2015-01-01 06:00:00       9200.0  2015              1            3
# 2015-01-01 07:00:00       9657.0  2015              1            3
# 2015-01-01 08:00:00      10032.0  2015              1            3
# 2015-01-01 09:00:00      10072.0  2015              1            3
# 2015-01-01 10:00:00       9932.0  2015              1            3
# 2015-01-01 11:00:00       9980.0  2015              1            3
# 2015-01-01 12:00:00       9392.0  2015              1            3
# ...

# %%
df['System_load']=pd.to_numeric(df['System_load'],errors='coerce')

# %%
df.to_csv('C:\\Users\\arif\\OneDrive\\Journal Paper\\Code\\Irshad\\Dataset\\7_Dataset.csv', index=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 46728 entries, 2015-01-01 00:00:00 to 2020-04-30 23:00:00
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   System_load    46728 non-null  float64
#  1   Year           46728 non-null  int64
#  2   Month_of_year  46728 non-null  int64
#  3   Day_Of_Week    46728 non-null  int64
#  4   hour_of_day    46728 non-null  int64
#  5   holiday        46728 non-null  int64
#  6   winter_peak    46728 non-null  int32
#  7   Spring_Peak    46728 non-null  int32
#  8   Summer_Peak    46728 non-null  int32
#  9   Autumn_peak    46728 non-null  int32
# dtypes: float64(1), int32(4), int64(5)
# memory usage: 3.2 MB

# %%
df
# Out:
#                      System_load  Year  Month_of_year  Day_Of_Week  \
# date_and_hour
# 2015-01-01 00:00:00       8288.0  2015              1            3
# 2015-01-01 01:00:00       8099.0  2015              1            3
# 2015-01-01 02:00:00       7994.0  2015              1            3
# 2015-01-01 03:00:00       7965.0  2015              1            3
# 2015-01-01 04:00:00       8120.0  2015              1            3
# ...                          ...   ...            ...          ...
# 2020-04-30 19:00:00      16858.0  2020              4            3
# 2020-04-30 20:00:00      17105.0  2020              4            3
# 2020-04-30 21:00:00      16824.0  2020              4            3
# 2020-04-30 22:00:00      16332.0  2020              4            3
# 2020-04-30 23:00:00      15003.0  2020              4            3
#
#                      hour_of_day  holiday  winter_peak  Spring_Peak  \
# date_and_hour
# ...

# %%
df.loc['2015-10-01']
# Out:
#             System_load  Year  Month_of_year  Day_Of_Week  hour_of_day  \
# Date
# 2015-10-01      11385.0  2015             10            3            0
# 2015-10-01      11291.0  2015             10            3            1
# 2015-10-01      11202.0  2015             10            3            2
# 2015-10-01      10689.0  2015             10            3            3
# 2015-10-01      10624.0  2015             10            3            4
# 2015-10-01      10042.0  2015             10            3            5
# 2015-10-01      10622.0  2015             10            3            6
# 2015-10-01      10954.0  2015             10            3            7
# 2015-10-01      11604.0  2015             10            3            8
# 2015-10-01      12075.0  2015             10            3            9
# 2015-10-01      12269.0  2015             10            3           10
# 2015-10-01      12570.0  2015             10            3           11
# ...

# %%
df = pd.read_csv('C:\\Users\\arif\\OneDrive\\Journal Paper\\Code\\Irshad\\Dataset\\7_Dataset.csv')

# %%
# will fill the remaing by interpolation
df.isnull().sum()
# Out:
# date_and_hour    0
# System_load      0
# Year             0
# Month_of_year    0
# Day_Of_Week      0
# hour_of_day      0
# holiday          0
# winter_peak      0
# Spring_Peak      0
# Summer_Peak      0
# Autumn_peak      0
# dtype: int64
