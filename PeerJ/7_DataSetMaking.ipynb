# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('C:\\Users\\Syed Hasnat\\OneDrive\\Journal Paper\\Code\\Irshad\\Dataset\\3_Outlier_Identified.csv', parse_dates=['date_and_hour'])

# %%
df
# Out:
#             date_and_hour  System_load
# 0     2015-01-01 00:00:00       8288.0
# 1     2015-01-01 01:00:00       8099.0
# 2     2015-01-01 02:00:00       7994.0
# 3     2015-01-01 03:00:00       7965.0
# 4     2015-01-01 04:00:00       8120.0
# ...                   ...          ...
# 46723 2020-04-30 19:00:00      16858.0
# 46724 2020-04-30 20:00:00      17105.0
# 46725 2020-04-30 21:00:00      16824.0
# 46726 2020-04-30 22:00:00      16332.0
# 46727 2020-04-30 23:00:00      15003.0
#
# [46728 rows x 2 columns]

# %%
df['Date'] = df['date_and_hour'].dt.date
df['Year']=df['date_and_hour'].dt.year
df['Month_of_year']=df['date_and_hour'].dt.month
df['Day_Of_Week']=df['date_and_hour'].dt.weekday
df['hour_of_day']=df['date_and_hour'].dt.hour
#df['Day']=df['date_and_hour'].dt.day
#df['Date']=df['Year'].astype(str) + "/" + df['Month'].astype(str) +"/"+ df['Day'].astype(str)
#df['Date']=pd.to_datetime(df['Date'])
#df.set_index('Date', inplace=True)
df.head()
# Out:
#         date_and_hour  System_load        Date  Year  Month_of_year  \
# 0 2015-01-01 00:00:00       8288.0  2015-01-01  2015              1
# 1 2015-01-01 01:00:00       8099.0  2015-01-01  2015              1
# 2 2015-01-01 02:00:00       7994.0  2015-01-01  2015              1
# 3 2015-01-01 03:00:00       7965.0  2015-01-01  2015              1
# 4 2015-01-01 04:00:00       8120.0  2015-01-01  2015              1
#
#    Day_Of_Week  hour_of_day
# 0            3            0
# 1            3            1
# 2            3            2
# 3            3            3
# 4            3            4

# %%
df.drop('date_and_hour', axis=1, inplace=True)

# %%
df
# Out:
#        System_load        Date  Year  Month_of_year  Day_Of_Week  hour_of_day
# 0           8288.0  2015-01-01  2015              1            3            0
# 1           8099.0  2015-01-01  2015              1            3            1
# 2           7994.0  2015-01-01  2015              1            3            2
# 3           7965.0  2015-01-01  2015              1            3            3
# 4           8120.0  2015-01-01  2015              1            3            4
# ...            ...         ...   ...            ...          ...          ...
# 46723      16858.0  2020-04-30  2020              4            3           19
# 46724      17105.0  2020-04-30  2020              4            3           20
# 46725      16824.0  2020-04-30  2020              4            3           21
# 46726      16332.0  2020-04-30  2020              4            3           22
# 46727      15003.0  2020-04-30  2020              4            3           23
#
# [46728 rows x 6 columns]

# %%
df.set_index('Date', inplace=True)

# %%
df
# Out:
#             System_load  Year  Month_of_year  Day_Of_Week  hour_of_day
# Date
# 2015-01-01       8288.0  2015              1            3            0
# 2015-01-01       8099.0  2015              1            3            1
# 2015-01-01       7994.0  2015              1            3            2
# 2015-01-01       7965.0  2015              1            3            3
# 2015-01-01       8120.0  2015              1            3            4
# ...                 ...   ...            ...          ...          ...
# 2020-04-30      16858.0  2020              4            3           19
# 2020-04-30      17105.0  2020              4            3           20
# 2020-04-30      16824.0  2020              4            3           21
# 2020-04-30      16332.0  2020              4            3           22
# 2020-04-30      15003.0  2020              4            3           23
#
# [46728 rows x 5 columns]

# %%
holidays = pd.concat(map(pd.read_csv, ['E:\\DataSets\\ShortTermLF\\NTDC\\2015.csv', 'E:\\DataSets\\ShortTermLF\\NTDC\\2016.csv','E:\\DataSets\\ShortTermLF\\NTDC\\2017.csv', 'E:\\DataSets\\ShortTermLF\\NTDC\\2018.csv','E:\\DataSets\\ShortTermLF\\NTDC\\2019.csv', 'E:\\DataSets\\ShortTermLF\\NTDC\\2020.csv']), ignore_index=True)
holidays.to_csv('E:\\DataSets\\ShortTermLF\\NTDC\\_2015_2020_holidays.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [11], in <cell line: 1>()
# ----> 1 holidays = pd.concat(map(pd.read_csv, ['E:\\DataSets\\ShortTermLF\\NTDC\\2015.csv', 'E:\\DataSets\\ShortTermLF\\NTDC\\2016.csv','E:\\DataSets\\ShortTermLF\\NTDC\\2017.csv', 'E:\\DataSets\\ShortTermLF\\NTDC\\2018.csv','E:\\DataSets\\ShortTermLF\\NTDC\\2019.csv', 'E:\\DataSets\\ShortTermLF\\NTDC\\2020.csv']), ignore_index=True)
#       2 holidays.to_csv('E:\\DataSets\\ShortTermLF\\NTDC\\_2015_2020_holidays.csv', index=False)
#
# File C:\ProgramData\Anaconda3\envs\py39\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
# ...

# %%
holidays=pd.read_csv('E:\\DataSets\\ShortTermLF\\NTDC\\_2015_2020_holidays.csv', parse_dates=['Date'])
holidays
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [12], in <cell line: 1>()
# ----> 1 holidays=pd.read_csv('E:\\DataSets\\ShortTermLF\\NTDC\\_2015_2020_holidays.csv', parse_dates=['Date'])
#       2 holidays
#
# File C:\ProgramData\Anaconda3\envs\py39\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
holidays.drop(['Day','Type','Comments'],axis=1, inplace=True)

# %%
holidays.set_index('Date', inplace=True)

# %%
holidays = holidays.iloc[0:143]

# %%
holidays
# Out:
#                             Holiday Name
# Date
# 2015-01-03             Eid Milad-un-Nabi
# 2015-01-20        Chehlum of APS martyrs
# 2015-02-05        Kashmir Solidarity Day
# 2015-03-23                  Pakistan Day
# 2015-04-04                Public Holiday
# ...                                  ...
# 2020-03-27                Public Holiday
# 2020-03-28                Public Holiday
# 2020-04-04  Death of Zulfikar Ali Bhutto
# 2020-04-24                       Ramazan
# 2020-04-27                  Bank Holiday
#
# [143 rows x 1 columns]

# %%
result = pd.merge(df, holidays, left_index=True, right_index=True, how="left")
result
# Out:
#             System_load  Year  Month_of_year  Day_Of_Week  hour_of_day  \
# Date
# 2015-01-01       8288.0  2015              1            3            0
# 2015-01-01       8099.0  2015              1            3            1
# 2015-01-01       7994.0  2015              1            3            2
# 2015-01-01       7965.0  2015              1            3            3
# 2015-01-01       8120.0  2015              1            3            4
# ...                 ...   ...            ...          ...          ...
# 2020-04-30      16858.0  2020              4            3           19
# 2020-04-30      17105.0  2020              4            3           20
# 2020-04-30      16824.0  2020              4            3           21
# 2020-04-30      16332.0  2020              4            3           22
# 2020-04-30      15003.0  2020              4            3           23
#
#            Holiday Name
# Date
# 2015-01-01          NaN
# 2015-01-01          NaN
# 2015-01-01          NaN
# ...

# %%
NationalHolidays = result['Holiday Name'].notnull().astype("int")
weekend = (result['Day_Of_Week']>=5).astype("int")
holiday = weekend | NationalHolidays 
result['holiday'] = holiday
result.drop(['Holiday Name'],axis=1,inplace=True)

# %%
result.reset_index(inplace=True)

# %%
result
# Out:
#             Date  System_load  Year  Month_of_year  Day_Of_Week  hour_of_day  \
# 0     2015-01-01       8288.0  2015              1            3            0
# 1     2015-01-01       8099.0  2015              1            3            1
# 2     2015-01-01       7994.0  2015              1            3            2
# 3     2015-01-01       7965.0  2015              1            3            3
# 4     2015-01-01       8120.0  2015              1            3            4
# ...          ...          ...   ...            ...          ...          ...
# 46723 2020-04-30      16858.0  2020              4            3           19
# 46724 2020-04-30      17105.0  2020              4            3           20
# 46725 2020-04-30      16824.0  2020              4            3           21
# 46726 2020-04-30      16332.0  2020              4            3           22
# 46727 2020-04-30      15003.0  2020              4            3           23
#
#        holiday
# 0            0
# ...

# %%
result.to_csv('C:\\Users\\arif\\OneDrive\\Journal Paper\\Code\\Irshad\\Dataset\\5_Dataset_cyclic_holi.csv', index=False)

# %% [markdown]
# # Practus work

# %%
Holiday = result['Holiday Name'].notnull().astype("int")
Holiday.loc['2015-01-03':'2015-01-04']
# Out:
# 2015-01-03    1
# 2015-01-03    1
# 2015-01-03    1
# 2015-01-03    1
# 2015-01-03    1
# 2015-01-03    1
# 2015-01-03    1
# 2015-01-03    1
# 2015-01-03    1
# 2015-01-03    1
# 2015-01-03    1
# 2015-01-03    1
# 2015-01-03    1
# 2015-01-03    1
# 2015-01-03    1
# 2015-01-03    1
# 2015-01-03    1
# 2015-01-03    1
# 2015-01-03    1
# 2015-01-03    1
# 2015-01-03    1
# 2015-01-03    1
# 2015-01-03    1
# 2015-01-03    1
# 2015-01-04    0
# 2015-01-04    0
# 2015-01-04    0
# 2015-01-04    0
# 2015-01-04    0
# 2015-01-04    0
# 2015-01-04    0
# 2015-01-04    0
# 2015-01-04    0
# 2015-01-04    0
# 2015-01-04    0
# 2015-01-04    0
# 2015-01-04    0
# 2015-01-04    0
# 2015-01-04    0
# 2015-01-04    0
# 2015-01-04    0
# 2015-01-04    0
# 2015-01-04    0
# 2015-01-04    0
# 2015-01-04    0
# 2015-01-04    0
# 2015-01-04    0
# 2015-01-04    0
# Name: Holiday Name, dtype: int32

# %%
weekend = (result['Day_Of_Week']>=5).astype("int")
weekend.loc['2015-01-03':'2015-01-04']
# Out:
# 2015-01-03    1
# 2015-01-03    1
# 2015-01-03    1
# 2015-01-03    1
# 2015-01-03    1
# 2015-01-03    1
# 2015-01-03    1
# 2015-01-03    1
# 2015-01-03    1
# 2015-01-03    1
# 2015-01-03    1
# 2015-01-03    1
# 2015-01-03    1
# 2015-01-03    1
# 2015-01-03    1
# 2015-01-03    1
# 2015-01-03    1
# 2015-01-03    1
# 2015-01-03    1
# 2015-01-03    1
# 2015-01-03    1
# 2015-01-03    1
# 2015-01-03    1
# 2015-01-03    1
# 2015-01-04    1
# 2015-01-04    1
# 2015-01-04    1
# 2015-01-04    1
# 2015-01-04    1
# 2015-01-04    1
# 2015-01-04    1
# 2015-01-04    1
# 2015-01-04    1
# 2015-01-04    1
# 2015-01-04    1
# 2015-01-04    1
# 2015-01-04    1
# 2015-01-04    1
# 2015-01-04    1
# 2015-01-04    1
# 2015-01-04    1
# 2015-01-04    1
# 2015-01-04    1
# 2015-01-04    1
# 2015-01-04    1
# 2015-01-04    1
# 2015-01-04    1
# 2015-01-04    1
# Name: Day_Of_Week, dtype: int32

# %%
result.drop(['Holiday Name'],axis=1,inplace=True)

# %%
result
# Out:
#             System_load  HOUR  Day_Of_Week  Year  holiday
# 2015-01-01         8288     1            3  2015        0
# 2015-01-01         8099     2            3  2015        0
# 2015-01-01         7994     3            3  2015        0
# 2015-01-01         7965     4            3  2015        0
# 2015-01-01         8120     5            3  2015        0
# ...                 ...   ...          ...   ...      ...
# 2020-04-30        16858    20            3  2020        0
# 2020-04-30        17105    21            3  2020        0
# 2020-04-30        16824    22            3  2020        0
# 2020-04-30        16332    23            3  2020        0
# 2020-04-30        15003    24            3  2020        0
#
# [46608 rows x 5 columns]

# %%
holiday = weekend | Holiday

# %%
holiday.loc['2015-01-03':'2015-01-04']
# Out:
# 2015-01-03    1
# 2015-01-03    1
# 2015-01-03    1
# 2015-01-03    1
# 2015-01-03    1
# 2015-01-03    1
# 2015-01-03    1
# 2015-01-03    1
# 2015-01-03    1
# 2015-01-03    1
# 2015-01-03    1
# 2015-01-03    1
# 2015-01-03    1
# 2015-01-03    1
# 2015-01-03    1
# 2015-01-03    1
# 2015-01-03    1
# 2015-01-03    1
# 2015-01-03    1
# 2015-01-03    1
# 2015-01-03    1
# 2015-01-03    1
# 2015-01-03    1
# 2015-01-03    1
# 2015-01-04    1
# 2015-01-04    1
# 2015-01-04    1
# 2015-01-04    1
# 2015-01-04    1
# 2015-01-04    1
# 2015-01-04    1
# 2015-01-04    1
# 2015-01-04    1
# 2015-01-04    1
# 2015-01-04    1
# 2015-01-04    1
# 2015-01-04    1
# 2015-01-04    1
# 2015-01-04    1
# 2015-01-04    1
# 2015-01-04    1
# 2015-01-04    1
# 2015-01-04    1
# 2015-01-04    1
# 2015-01-04    1
# 2015-01-04    1
# 2015-01-04    1
# 2015-01-04    1
# dtype: int32

# %%
holiday
# Out:
# 2015-01-01    0
# 2015-01-01    0
# 2015-01-01    0
# 2015-01-01    0
# 2015-01-01    0
#              ..
# 2020-04-30    0
# 2020-04-30    0
# 2020-04-30    0
# 2020-04-30    0
# 2020-04-30    0
# Length: 46608, dtype: int32

# %%
result['holiday'] = holiday

# %%
result.loc['2016-12-30':'2016-12-31']
# Out:
#             System_load  HOUR  Day_Of_Week  Year Holiday Name  holiday
# 2016-12-30         8557     1            4  2016          NaN        0
# 2016-12-30         7571     2            4  2016          NaN        0
# 2016-12-30         7450     3            4  2016          NaN        0
# 2016-12-30         6918     4            4  2016          NaN        0
# 2016-12-30         6938     5            4  2016          NaN        0
# 2016-12-30         7101     6            4  2016          NaN        0
# 2016-12-30         8007     7            4  2016          NaN        0
# 2016-12-30         8324     8            4  2016          NaN        0
# 2016-12-30         8306     9            4  2016          NaN        0
# 2016-12-30         8763    10            4  2016          NaN        0
# 2016-12-30         9365    11            4  2016          NaN        0
# 2016-12-30        10108    12            4  2016          NaN        0
# ...

# %%
result[holiday==0]
# Out:
#             System_load  HOUR  Day_Of_Week  Year Holiday Name  holiday
# 2015-01-01         8288     1            3  2015          NaN        0
# 2015-01-01         8099     2            3  2015          NaN        0
# 2015-01-01         7994     3            3  2015          NaN        0
# 2015-01-01         7965     4            3  2015          NaN        0
# 2015-01-01         8120     5            3  2015          NaN        0
# ...                 ...   ...          ...   ...          ...      ...
# 2020-04-30        16858    20            3  2020          NaN        0
# 2020-04-30        17105    21            3  2020          NaN        0
# 2020-04-30        16824    22            3  2020          NaN        0
# 2020-04-30        16332    23            3  2020          NaN        0
# 2020-04-30        15003    24            3  2020          NaN        0
#
# [30382 rows x 6 columns]

# %%
weekendHoliday = dataset['Holiday Name'].notnull().astype("int")

# %%
### https://www.skytowner.com/explore/mapping_nan_values_to_0_and_non_nan_values_to_1_in_pandas_dataframe
weekendHoliday = dataset['Holiday Name'].notnull().astype("int")
dataset
# Out:
# 2015-01-01    1
# 2015-01-01    1
# 2015-01-01    1
# 2015-01-01    1
# 2015-01-01    1
#              ..
# 2020-04-30    1
# 2020-04-30    1
# 2020-04-30    1
# 2020-04-30    1
# 2020-04-30    1
# Name: Holiday Name, Length: 46608, dtype: int32

# %%
dataset[dataset['Day_Of_Week']==5]
# Out:
# Empty DataFrame
# Columns: [System_load, HOUR, Day_Of_Week, Year, Holiday Name]
# Index: []

# %%
52*24*5+4*2*24+5*2*24
# Out:
# 6672

# %%
print('holidays :', holidays.shape)
print('data     :', data.shape)
print('holidays will be duplicated with 24:', 152*24)
print('Non duplicated:', 46608 - 152*24)
# Out:
# holidays : (152, 1)
# data     : (46608, 4)
# holidays will be duplicated with 24: 3648
# Non duplicated: 42960

# %%
result=data.join(holidays)

# %%
print('non leaf year :', 24*31*7 + 24*30*4 + 24*28*1)
print('leaf year     :', 24*31*7 + 24*30*4 + 24*29*1)
print('first 4 months:', 24*31*2 + 24*30*1 + 24*29*1)
print('total         :', 4*(24*31*7+24*30*4+24*28*1)  +  (24*31*7+24*30*4+24*29*1)  +  (24*31*2+24*30*1+24*29*1))
print('difference    :', 46728-46608)
# Out:
# non leaf year : 8760
# leaf year     : 8784
# first 4 months: 2904
# total         : 46728
# difference    : 120

# %%
data.groupby('Year').count()
# Out:
#       System_load  HOUR  Day_Of_Week
# Year
# 2015         8736  8736         8736
# 2016         8736  8736         8736
# 2017         8736  8736         8736
# 2018         8736  8736         8736
# 2019         8760  8760         8760
# 2020         2904  2904         2904

# %%
8736*4+8760+2904
# Out:
# 46608

# %%
result.groupby('Year').count()
# Out:
#       System_load  HOUR  Day_Of_Week  Holiday Name
# Year
# 2015         8736  8736         8736           624
# 2016         8736  8736         8736           576
# 2017         8736  8736         8736           623
# 2018         8736  8736         8736           672
# 2019         8760  8760         8760           622
# 2020         2904  2904         2904           314

# %%
8832+8760*3+8807+2904
# Out:
# 46823

# %%
46823-46608
# Out:
# 215

# %%
print("2015: " , 8832-8736)
print("2016: " , 8760-8736)
print("2017: " , 8760-8736)
print("2018: " , 8760-8736)
print("2019: " , 8808-8760)
# Out:
# 2015:  96
# 2016:  24
# 2017:  24
# 2018:  24
# 2019:  48

# %%
96+24*3+48
# Out:
# 216

# %%
result
# Out:
#             System_load  HOUR  Day_Of_Week  Year Holiday Name
# 2015-01-01         8288     1            3  2015          NaN
# 2015-01-01         8099     2            3  2015          NaN
# 2015-01-01         7994     3            3  2015          NaN
# 2015-01-01         7965     4            3  2015          NaN
# 2015-01-01         8120     5            3  2015          NaN
# ...                 ...   ...          ...   ...          ...
# 2020-04-30        16858    20            3  2020          NaN
# 2020-04-30        17105    21            3  2020          NaN
# 2020-04-30        16824    22            3  2020          NaN
# 2020-04-30        16332    23            3  2020          NaN
# 2020-04-30        15003    24            3  2020          NaN
#
# [46823 rows x 5 columns]

# %%
result = pd.merge(data, holidays, left_index=True, right_index=True, how="inner")

# %%
result
# Out:
#             System_load  HOUR  Day_Of_Week  Year       Holiday Name
# 2015-01-03         8175     1            5  2015  Eid Milad-un-Nabi
# 2015-01-03         8017     2            5  2015  Eid Milad-un-Nabi
# 2015-01-03         7965     3            5  2015  Eid Milad-un-Nabi
# 2015-01-03         7818     4            5  2015  Eid Milad-un-Nabi
# 2015-01-03         7953     5            5  2015  Eid Milad-un-Nabi
# ...                 ...   ...          ...   ...                ...
# 2020-04-27        15218    20            0  2020       Bank Holiday
# 2020-04-27        15493    21            0  2020       Bank Holiday
# 2020-04-27        15116    22            0  2020       Bank Holiday
# 2020-04-27        14387    23            0  2020       Bank Holiday
# 2020-04-27        12549    24            0  2020       Bank Holiday
#
# [3646 rows x 5 columns]

# %%
result = data.join(holidays)

# %%
print('non leaf year :', 24*31*7 + 24*30*4 + 24*28*1)
print('leaf year     :', 24*31*7 + 24*30*4 + 24*29*1)
print('first 4 months:', 24*31*2 + 24*30*1 + 24*29*1)
print('total         :', 4*(24*31*7+24*30*4+24*28*1)  +  (24*31*7+24*30*4+24*29*1)  +  (24*31*2+24*30*1+24*29*1))
print('difference    :', 46728-46608)
# Out:
# non leaf year : 8760
# leaf year     : 8784
# first 4 months: 2904
# total         : 46728
# difference    : 120

# %%
data.groupby('Year').count()
# Out:
#       System_load  HOUR  Day_Of_Week
# Year
# 2015         8736  8736         8736
# 2016         8736  8736         8736
# 2017         8736  8736         8736
# 2018         8736  8736         8736
# 2019         8760  8760         8760
# 2020         2904  2904         2904

# %%
result.groupby('Year').count()
# Out:
#       System_load  HOUR  Day_Of_Week  Holiday Name
# Year
# 2015         8832  8832         8832           720
# 2016         8760  8760         8760           600
# 2017         8760  8760         8760           647
# 2018         8760  8760         8760           696
# 2019         8807  8807         8807           669
# 2020         2904  2904         2904           314

# %%
result['Holiday Name'].isna().sum()
# Out:
# 43177

# %%
46823-43177
# Out:
# 3646

# %%
152*24
# Out:
# 3648

# %%
### https://www.skytowner.com/explore/mapping_nan_values_to_0_and_non_nan_values_to_1_in_pandas_dataframe
dataset = result.notnull().astype("int")

# %%
dataset
# Out:
#             System_load  HOUR  Day_Of_Week  Year  Holiday Name
# Date_Time
# 2015-01-01            1     1            1     1             0
# 2015-01-01            1     1            1     1             0
# 2015-01-01            1     1            1     1             0
# 2015-01-01            1     1            1     1             0
# 2015-01-01            1     1            1     1             0
# ...                 ...   ...          ...   ...           ...
# 2020-04-30            1     1            1     1             0
# 2020-04-30            1     1            1     1             0
# 2020-04-30            1     1            1     1             0
# 2020-04-30            1     1            1     1             0
# 2020-04-30            1     1            1     1             0
#
# [46823 rows x 5 columns]

# %%
46823-46608
# Out:
# 215

# %%
result.head(50)
# Out:
#             System_load  HOUR  Day_Of_Week  Year       Holiday Name
# Date_Time
# 2015-01-01         8288     1            3  2015                NaN
# 2015-01-01         8099     2            3  2015                NaN
# 2015-01-01         7994     3            3  2015                NaN
# 2015-01-01         7965     4            3  2015                NaN
# 2015-01-01         8120     5            3  2015                NaN
# 2015-01-01         8462     6            3  2015                NaN
# 2015-01-01         9200     7            3  2015                NaN
# 2015-01-01         9657     8            3  2015                NaN
# 2015-01-01        10032     9            3  2015                NaN
# 2015-01-01        10072    10            3  2015                NaN
# 2015-01-01         9932    11            3  2015                NaN
# 2015-01-01         9980    12            3  2015                NaN
# 2015-01-01         9392    13            3  2015                NaN
# ...

# %%
left = pd.DataFrame({"A": ["A0", "A1", "A2","A3"], "B": ["B0", "B1", "B2","B3"]}, index=["K0", "K0", "K2","K3"])
left
# Out:
#      A   B
# K0  A0  B0
# K0  A1  B1
# K2  A2  B2
# K3  A3  B3

# %%
right = pd.DataFrame({"C": ["C0", "C2", "C3"], "D": ["D0", "D2", "D3"]}, index=["K0", "K2", "K3"])
right
# Out:
#      C   D
# K0  C0  D0
# K2  C2  D2
# K3  C3  D3

# %%
pd.merge(left, right, left_index=True, right_index=True, how="outer")
# Out:
#      A   B   C   D
# K0  A0  B0  C0  D0
# K0  A1  B1  C0  D0
# K2  A2  B2  C2  D2
# K3  A3  B3  C3  D3

# %%
pd.merge(left, right, left_index=True, right_index=True, how="inner")
# Out:
#      A   B   C   D
# K0  A0  B0  C0  D0
# K2  A2  B2  C2  D2
# K3  A3  B3  C3  D3

# %%
result
# Out:
#             System_load  HOUR  Day_Of_Week  Year Holiday Name
# Date_Time
# 2015-01-01         8288     1            3  2015          NaN
# 2015-01-01         8099     2            3  2015          NaN
# 2015-01-01         7994     3            3  2015          NaN
# 2015-01-01         7965     4            3  2015          NaN
# 2015-01-01         8120     5            3  2015          NaN
# ...                 ...   ...          ...   ...          ...
# 2020-04-30        16858    20            3  2020          NaN
# 2020-04-30        17105    21            3  2020          NaN
# 2020-04-30        16824    22            3  2020          NaN
# 2020-04-30        16332    23            3  2020          NaN
# 2020-04-30        15003    24            3  2020          NaN
#
# [46823 rows x 5 columns]

# %%
result = data.join(holidays, how="outer")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-c473a0a9b482> in <module>
# ----> 1 result = data.join(holidays, how="outer")
#
# ~\Anaconda3\envs\irshad1\lib\site-packages\pandas\core\frame.py in join(self, other, on, how, lsuffix, rsuffix, sort)
#    7207         """
#    7208         return self._join_compat(
# -> 7209             other, on=on, how=how, lsuffix=lsuffix, rsuffix=rsuffix, sort=sort
#    7210         )
#    7211
#
# ~\Anaconda3\envs\irshad1\lib\site-packages\pandas\core\frame.py in _join_compat(self, other, on, how, lsuffix, rsuffix, sort)
#    7230                 right_index=True,
#    7231                 suffixes=(lsuffix, rsuffix),
# -> 7232                 sort=sort,
#    7233             )
#    7234         else:
#
# ...

# %%
data=pd.concat([data,holidays], join='outer',ignore_index=False)
data
# Out:
#             System_load  HOUR  Day_Of_Week    Year  Day Holiday Name Type  \
# 2015-01-01       8288.0   1.0          3.0  2015.0  NaN          NaN  NaN
# 2015-01-01       8099.0   2.0          3.0  2015.0  NaN          NaN  NaN
# 2015-01-01       7994.0   3.0          3.0  2015.0  NaN          NaN  NaN
# 2015-01-01       7965.0   4.0          3.0  2015.0  NaN          NaN  NaN
# 2015-01-01       8120.0   5.0          3.0  2015.0  NaN          NaN  NaN
# ...                 ...   ...          ...     ...  ...          ...  ...
# NaT                 NaN   NaN          NaN     NaN  NaN          NaN  NaN
# NaT                 NaN   NaN          NaN     NaN  NaN          NaN  NaN
# NaT                 NaN   NaN          NaN     NaN  NaN          NaN  NaN
# NaT                 NaN   NaN          NaN     NaN  NaN          NaN  NaN
# NaT                 NaN   NaN          NaN     NaN  NaN          NaN  NaN
#
#            Comments
# 2015-01-01      NaN
# 2015-01-01      NaN
# ...

# %%
data[]
# Out:
#   File "<ipython-input-20-1527323af517>", line 1
#     data[]
#          ^
# SyntaxError: invalid syntax

# %%
46777-46608
# Out:
# 169

# %%
data.head(50)
# Out:
#             System_load  HOUR  Day_Of_Week  Year
# Date_Time
# 2015-01-01         8288     1            3  2015
# 2015-01-01         8099     2            3  2015
# 2015-01-01         7994     3            3  2015
# 2015-01-01         7965     4            3  2015
# 2015-01-01         8120     5            3  2015
# 2015-01-01         8462     6            3  2015
# 2015-01-01         9200     7            3  2015
# 2015-01-01         9657     8            3  2015
# 2015-01-01        10032     9            3  2015
# 2015-01-01        10072    10            3  2015
# 2015-01-01         9932    11            3  2015
# 2015-01-01         9980    12            3  2015
# 2015-01-01         9392    13            3  2015
# 2015-01-01         9488    14            3  2015
# 2015-01-01         9270    15            3  2015
# 2015-01-01         9209    16            3  2015
# 2015-01-01         9369    17            3  2015
# 2015-01-01         9435    18            3  2015
# ...
