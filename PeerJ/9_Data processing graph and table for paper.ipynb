# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import pdb
import matplotlib
import seaborn as sns

# %%
df = pd.read_csv('C:\\Users\\arif\\OneDrive\\Journal Paper\\Code\\Irshad\\Dataset\\7_Dataset.csv', parse_dates=['date_and_hour'], index_col='date_and_hour')

# %%
df
# Out:
#                      System_load  Year  Month_of_year  Day_Of_Week  \
# date_and_hour
# 2015-01-01 00:00:00       8288.0  2015              1            3
# 2015-01-01 01:00:00       8099.0  2015              1            3
# 2015-01-01 02:00:00       7994.0  2015              1            3
# 2015-01-01 03:00:00       7965.0  2015              1            3
# 2015-01-01 04:00:00       8120.0  2015              1            3
# ...                          ...   ...            ...          ...
# 2020-04-30 19:00:00      16858.0  2020              4            3
# 2020-04-30 20:00:00      17105.0  2020              4            3
# 2020-04-30 21:00:00      16824.0  2020              4            3
# 2020-04-30 22:00:00      16332.0  2020              4            3
# 2020-04-30 23:00:00      15003.0  2020              4            3
#
#                      hour_of_day  holiday  winter_peak  Spring_Peak  \
# date_and_hour
# ...

# %%
from pandas import read_csv
from matplotlib import pyplot
from statsmodels.tsa.seasonal import seasonal_decompose
series = df.groupby('Year').mean()['System_load']
result = seasonal_decompose(series, model='multiplicative')
result.plot()
pyplot.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12928\1001546795.py in <module>
#       3 from statsmodels.tsa.seasonal import seasonal_decompose
#       4 series = df.groupby('Year').mean()['System_load']
# ----> 5 result = seasonal_decompose(series, model='multiplicative')
#       6 result.plot()
#       7 pyplot.show()
#
# ~\Anaconda3\envs\time2\lib\site-packages\statsmodels\tsa\seasonal.py in seasonal_decompose(x, model, filt, period, two_sided, extrapolate_trend)
#     158         else:
#     159             raise ValueError(
# --> 160                 "You must specify a period or x must be a pandas object with "
#     161                 "a PeriodIndex or a DatetimeIndex with a freq not set to None"
#     162             )
#
# ...

# %%
df.groupby('Year').mean()['System_load']
# Out:
# Year
# 2015    11164.785297
# 2016    11794.138795
# 2017    13376.594325
# 2018    14222.364848
# 2019    14163.559646
# 2020    10286.292528
# Name: System_load, dtype: float64

# %%
df['System_load']=pd.to_numeric(df['System_load'],errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 46728 entries, 2015-01-01 00:00:00 to 2020-04-30 23:00:00
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   System_load    46728 non-null  float64
#  1   Year           46728 non-null  int64
#  2   Month_of_year  46728 non-null  int64
#  3   Day_Of_Week    46728 non-null  int64
#  4   hour_of_day    46728 non-null  int64
#  5   holiday        46728 non-null  int64
#  6   winter_peak    46728 non-null  int64
#  7   Spring_Peak    46728 non-null  int64
#  8   Summer_Peak    46728 non-null  int64
#  9   Autumn_peak    46728 non-null  int64
# dtypes: float64(1), int64(9)
# memory usage: 3.9 MB

# %%
df[["System_load"]].describe()
# Out:
#         System_load
# count  46606.000000
# mean   12773.449148
# std     3548.918969
# min      473.000000
# 25%     9885.000000
# 50%    12034.500000
# 75%    15397.000000
# max    24786.000000

# %%
df = pd.read_csv('C:\\Users\\arif\\OneDrive\\Journal Paper\\Code\\Irshad\\Dataset\\7_Dataset.csv', parse_dates=['date_and_hour'], index_col='date_and_hour')

# %%
df[["System_load"]].describe()
# Out:
#         System_load
# count  46728.000000
# mean   12778.511658
# std     3545.568922
# min     1648.000000
# 25%     9886.000000
# 50%    12046.000000
# 75%    15402.000000
# max    22696.000000

# %%
df
# Out:
#             HOUR System_load
# Date
# 2015-01-01     1        8288
# 2015-01-01     2        8099
# 2015-01-01     3        7994
# 2015-01-01     4        7965
# 2015-01-01     5        8120
# ...          ...         ...
# 2020-04-30    20       16858
# 2020-04-30    21       17105
# 2020-04-30    22       16824
# 2020-04-30    23       16332
# 2020-04-30    24       15003
#
# [46608 rows x 2 columns]

# %%
df = pd.read_csv('C:\\Users\\arif\\OneDrive\\Journal Paper\\Code\\Irshad\\Dataset\\1_Originol_DataSet.csv', parse_dates=['Date'], index_col='Date')

# %%
df['System_load']=pd.to_numeric(df['System_load'],errors='coerce')

# %%
df.boxplot('System_load', grid=False)
# Out:
# <AxesSubplot:>

# %%
sns_plot = sns.boxplot( y='System_load', data=df, width=0.4)

# %%
sns_plot.figure.savefig('C:\\Users\\arif\\OneDrive\\Journal Paper\\Code\\Irshad\\Figure for paper\\1_Box_plot_outlier.png',dpi=1024)

# %%
df = pd.read_csv('C:\\Users\\arif\\OneDrive\\Journal Paper\\Code\\Irshad\\Dataset\\7_Dataset.csv', parse_dates=['date_and_hour'], index_col='date_and_hour')

# %%
df.groupby('Year').mean()
# Out:
#        System_load  Month_of_year  Day_Of_Week  hour_of_day   holiday  \
# Year
# 2015  11164.785297       6.526027     3.000000         11.5  0.286986
# 2016  11794.138795       6.513661     3.008197         11.5  0.289276
# 2017  13376.594325       6.526027     3.008219         11.5  0.290068
# 2018  14222.364848       6.526027     2.991781         11.5  0.287900
# 2019  14163.559646       6.526027     2.994521         11.5  0.287671
# 2020  10286.292528       2.495868     2.991736         11.5  0.284780
#
#       winter_peak  Spring_Peak  Summer_Peak  Autumn_peak
# Year
# 2015     0.051370     0.052511     0.052511     0.051941
# 2016     0.051799     0.052368     0.052368     0.051799
# 2017     0.051370     0.052511     0.052511     0.051941
# 2018     0.051370     0.052511     0.052511     0.051941
# 2019     0.051370     0.052511     0.052511     0.051941
# 2020     0.103306     0.105028     0.000000     0.000000

# %%
#plt.figure(figsize=(10, 10), constrained_layout=True)
plt.plot(df['System_load'])

# %%
df = pd.read_csv('C:\\Users\\arif\\OneDrive\\Journal Paper\\Code\\Irshad\\Dataset\\1_Originol_DataSet.csv', parse_dates=['Date'], index_col='Date')

# %%
plt.figure(figsize=(10, 10), constrained_layout=True)
plt.plot(df['System_load'])
plt.show()

# %%
df = pd.read_csv('C:\\Users\\arif\\OneDrive\\Journal Paper\\Code\\Irshad\\Dataset\\2_Missing_Values_Identified.csv', parse_dates=['date_and_hour'], index_col='date_and_hour')

# %%
plt.figure(figsize=(10, 10), constrained_layout=True)
plt.plot(df['System_load'])
plt.show()

# %%
pwd
# Out:
# 'C:\\Users\\arif\\Paper_NTDC'
